# %%
import pandas as pd
import numpy as np
import sympy as sym
from scipy import constants
import matplotlib.pyplot as plt
from scipy import optimize

# %%
path = "C:/Users/Darck/Modern_Phy_Lab/6 Doble Rendija/Double Slit.csv"

data = pd.read_csv(path, sep = ";")
data
# Out:
#      Longitud  Voltaje  Unnamed: 2
# 0       -4700    0.020         NaN
# 1       -4680    0.021         NaN
# 2       -4660    0.021         NaN
# 3       -4640    0.022         NaN
# 4       -4620    0.022         NaN
# ..        ...      ...         ...
# 397      3240    0.303         NaN
# 398      3260    0.309         NaN
# 399      3280    0.315         NaN
# 400      3300    0.321         NaN
# 401      3320    0.327         NaN
#
# [402 rows x 3 columns]

# %%
end = 402 - 60 
lenght = data["Longitud"].to_numpy()*1e-3 # Está en mm.
lenght[235] = 0.000001
lenght = lenght[130:402-78]
voltage = data["Voltaje"].to_numpy()
voltage = voltage[130:402-78]
voltage = voltage - 0.059
len(voltage), len(lenght)
# Out:
# (194, 194)

# %%
def GetPropagation(expr,vars,sigmas,measures):
    prop = 0
    for i in range(len(measures)):
        prop += expr.diff(var[i])**2 * sigmas[i]**2
    
    sigma = sym.sqrt(prop)
    #Sección para soltar el valor calculado y la incertidumbre del valor calculado. 

    sigma = sym.lambdify(var,sigma)
    mean = sym.lambdify(var,exp)
    return mean(*measures),sigma(*measures)

def New_Inc(inc1, inc2):
    return np.sqrt(inc1**2 + inc2**2)

lenght_inc = 10*1e-3
voltage_inc = 0.001

# %%
# Para poder medir hacer predicciones se ocupa generar una relación V [mV] vs θ:

vars = "y"
var = sym.symbols(vars, real = True)
#var = np.array([var])
sig = np.array([lenght_inc])
exp = np.arctan(var/470)
inc = np.array([])

data = GetPropagation(exp,var,sig,lenght)

theta = np.arctan(lenght/470)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'Mul' object has no attribute 'arctan'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_800/1840730175.py in <module>
#       5 #var = np.array([var])
#       6 sig = np.array([lenght_inc])
# ----> 7 exp = np.arctan(var/470)
#       8 inc = np.array([])
#       9
#
# TypeError: loop of ufunc does not support argument 0 of type Mul which has no callable arctan method

# %%
plt.figure(figsize=(12,8))
plt.scatter(lenght, voltage,  color = "#9A0B0B")
plt.xlabel(r"Longitud de la rejilla detectora [mm]", fontsize = 12)
plt.ylabel(r"Voltaje Medido [V]", fontsize = 12)
plt.grid()

# %%
plt.figure(figsize=(12,8))
plt.scatter(theta, voltage,  color = "#9A0B0B")
plt.xlabel(r"Ángulo $\theta$ de la Rejilla Detectora [rad]", fontsize = 12)
plt.ylabel(r"Voltaje Medido [V]", fontsize = 12)
plt.grid()
plt.savefig("VoltajeÁngulo.pdf")

# %%
a = 0.1
d = 0.457
lambda_ = 0.00067
l = 470

def Double_Slit(theta, I_0):
    alpha = (np.pi*a)/lambda_ * np.sin(theta)
    beta = (np.pi*d)/lambda_ * np.sin(theta)
    return (I_0**2) * (np.cos(beta))**2 * ((np.sin(alpha)/alpha)**2)

def Single_Slit(theta, I_0):
    alpha = (np.pi*a)/lambda_ * np.sin(theta)
    return I_0**2 *((np.sin(alpha)/alpha)**2)

# %%
theta_ = np.linspace(-0.005, 0.005, int(1e5))
popt, pcov = optimize.curve_fit(Double_Slit, theta, voltage)
ymodel = Double_Slit(theta_, *popt)
ymodel1 = Single_Slit(theta_, *popt)
plt.plot(theta_, ymodel)
plt.plot(theta_, ymodel1)

# %%
popt, pcov = optimize.curve_fit(Double_Slit, lenght, voltage)
popt, pcov
# Out:
# (array([0.775493]), array([[0.03746624]]))

# %%
new = Double_Slit(lenght, *popt)

# %%
plt.figure(figsize=(12,8))
plt.scatter(theta, voltage)
plt.plot(theta_, ymodel, color = "r")
plt.plot(theta_, ymodel1, color = "r")
plt.xlabel(r"Ángulo $\theta$ de la Rejilla Detectora [rad]", fontsize = 12)
plt.ylabel(r"Voltaje Medido [V]", fontsize = 12)
plt.grid()
plt.savefig("Intento.pdf")

# %%
voltage
# Out:
# array([0.003, 0.   , 0.   , 0.002, 0.007, 0.019, 0.031, 0.046, 0.066,
#        0.088, 0.108, 0.135, 0.158, 0.186, 0.208, 0.234, 0.26 , 0.288,
#        0.305, 0.327, 0.339, 0.35 , 0.356, 0.359, 0.356, 0.351, 0.341,
#        0.329, 0.311, 0.292, 0.271, 0.249, 0.223, 0.195, 0.171, 0.144,
#        0.122, 0.096, 0.075, 0.058, 0.049, 0.039, 0.031, 0.03 , 0.031,
#        0.037, 0.047, 0.064, 0.085, 0.114, 0.136, 0.174, 0.211, 0.244,
#        0.281, 0.312, 0.352, 0.381, 0.415, 0.443, 0.469, 0.488, 0.502,
#        0.512, 0.515, 0.514, 0.508, 0.495, 0.479, 0.456, 0.428, 0.394,
#        0.364, 0.325, 0.291, 0.255, 0.221, 0.181, 0.152, 0.125, 0.101,
#        0.081, 0.069, 0.061, 0.059, 0.062, 0.071, 0.086, 0.105, 0.131,
#        0.161, 0.203, 0.232, 0.273, 0.31 , 0.354, 0.395, 0.431, 0.467,
#        0.5  , 0.528, 0.553, 0.566, 0.577, 0.581, 0.601, 0.584, 0.578,
#        0.564, 0.56 , 0.546, 0.512, 0.479, 0.447, 0.41 , 0.366, 0.325,
#        0.283, 0.242, 0.212, 0.183, 0.142, 0.116, 0.095, 0.082, 0.069,
#        0.073, 0.068, 0.069, 0.071, 0.065, 0.17 , 0.202, 0.235, 0.27 ,
#        0.324, 0.359, 0.394, 0.423, 0.45 , 0.473, 0.494, 0.506, 0.513,
#        0.513, 0.509, 0.497, 0.481, 0.465, 0.434, 0.406, 0.38 , 0.339,
#        0.305, 0.276, 0.239, 0.202, 0.171, 0.142, 0.12 , 0.095, 0.078,
#        0.062, 0.053, 0.047, 0.046, 0.049, 0.058, 0.066, 0.084, 0.1  ,
#        0.119, 0.141, 0.158, 0.181, 0.202, 0.216, 0.235, 0.249, 0.26 ,
#        0.266, 0.27 , 0.272, 0.271, 0.265, 0.256, 0.244, 0.229, 0.211,
#        0.188, 0.164, 0.139, 0.116, 0.098])

# %%
value1 = d*np.sin(0.00145)/1
value2 = d*np.sin(0.00287)/2

# %%
(2*value1 + 2*value2)/4
# Out:
# 0.0006592219337552426
