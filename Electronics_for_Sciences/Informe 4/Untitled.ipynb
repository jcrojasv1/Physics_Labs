# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("circuito beta.csv")
df
# Out:
#         Record Length            2500   Points  -2.1000002E-3   0.0  \
# 0     Sample Interval  9.999999747E-6        s       -0.00209  0.00
# 1       Trigger Point    210.00002110  Samples       -0.00208  0.00
# 2                 NaN             NaN      NaN       -0.00207  0.00
# 3                 NaN             NaN      NaN       -0.00206  0.00
# 4                 NaN             NaN      NaN       -0.00205  0.00
# ...               ...             ...      ...            ...   ...
# 2494              NaN             NaN      NaN        0.02285  4.88
# 2495              NaN             NaN      NaN        0.02286  4.88
# 2496              NaN             NaN      NaN        0.02287  4.88
# 2497              NaN             NaN      NaN        0.02288  4.88
# 2498              NaN             NaN      NaN        0.02289  4.88
#
#       Unnamed: 5
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2494         NaN
# ...

# %%
df = df.drop(columns=['Record Length', 'Points', "2500", "Unnamed: 5"])
df
# Out:
#       -2.1000002E-3   0.0
# 0          -0.00209  0.00
# 1          -0.00208  0.00
# 2          -0.00207  0.00
# 3          -0.00206  0.00
# 4          -0.00205  0.00
# ...             ...   ...
# 2494        0.02285  4.88
# 2495        0.02286  4.88
# 2496        0.02287  4.88
# 2497        0.02288  4.88
# 2498        0.02289  4.88
#
# [2499 rows x 2 columns]

# %%
time = df["-2.1000002E-3"]
volt = df["0.0"]

# %%
plt.plot(time, volt)
plt.hlines( 5/np.sqrt(2), 0, 0.02289)
