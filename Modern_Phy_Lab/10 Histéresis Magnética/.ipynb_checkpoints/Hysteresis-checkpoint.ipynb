# %%
import pandas as pd
import numpy as np
import sympy as sym
from scipy import constants
import matplotlib.pyplot as plt
from scipy import optimize

# %%
inc_lenght = 0.05
inc_mass = 0.5
epsilon = 0.012

FN1_Volume = 4.25*4.0*15.03 # cm^3, es la aleación
FN1_Mass = 1868.8 # g
FN2_Volume = 4.01*4.00*15.05 # cm^3, es el hierro
FN2_Mass = 1620.5 # g

FN1_Density = FN1_Mass/FN1_Volume
FN2_Density = FN2_Mass/FN2_Volume

path1 = "C:/Users/Darck/Modern_Phy_Lab/10 Histéresis Magnética/data/FN1 - "
path2 = "C:/Users/Darck/Modern_Phy_Lab/10 Histéresis Magnética/data/FN2 - "

# %%
inc_area1 = inc_lenght*(1/4.25 + 1/4.0)*4.25*4.0
inc_volume1 = ((inc_area1/(4.25*4.0)) + (inc_lenght/15.03))*FN1_Volume
inc_density1 = (inc_volume1/FN1_Volume + inc_mass/FN1_Mass)*FN1_Density

FN1_Density, inc_density1 # BABBITT, BRONZE, TIN, WHITE METAL
# Out:
# (7.3139994520762395, 0.20376025160348316)

# %%
FN1_Volume, inc_volume1
# Out:
# (255.51, 7.049875)

# %%
inc_area2 = inc_lenght*(1/4.01 + 1/4.00)*4.01*4.00
inc_volume2 = ((inc_area2/(4.01*4.00)) + (inc_lenght/15.05))*FN2_Volume
inc_density2 = (inc_volume2/FN1_Volume + inc_mass/FN1_Mass)*FN2_Density

FN2_Density, inc_density2 # CAST IRON
# Out:
# (6.71286899031491, 0.18122426550854442)

# %%
FN2_Volume, inc_volume2
# Out:
# (241.402, 6.829525)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

FN1_SINEA = pd.read_csv(path1 + "SINE A.csv", sep=';')
X1_SINEA = FN1_SINEA["Corriente"]
Y1_SINEA = FN1_SINEA["Flujo"]

FN2_SINEA = pd.read_csv(path2 + "SINE A.csv", sep=';')
X2_SINEA = FN2_SINEA["Corriente"]
Y2_SINEA = FN2_SINEA["Flujo"]

ax1.scatter(X1_SINEA[35::], Y1_SINEA[35::], color = "#420404")
ax1.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax1.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax1.scatter(0.003, -0.23, color = "orange", marker = "o", s = 200)
ax1.scatter(0.006, 0.39, color = "orange", marker = "o", s = 200)
ax1.scatter(-0.289, 0.02, color = "red", marker = "o", s = 200)
ax1.scatter(0.207, -0.01, color = "red", marker = "o", s = 200)
ax1.scatter(-0.462, -0.34, color = "#AB0707", marker = "o", s = 200)
ax1.scatter(0.519, 0.53, color = "#AB0707", marker = "o", s = 200)

ax1.text(0.519 - 1*epsilon, 0.53 - 1.5*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(-0.462 - 0.8*epsilon, -0.34 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.207 - 1.1*epsilon, -0.01 - 1.6*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(-0.289 - 1.3*epsilon, 0.02 - 1.3*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(0.006 - 1.2*epsilon, 0.39 - 1.3*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.text(0.003 - 1.2*epsilon, -0.23 - 1.2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.grid()


ax2.scatter(X2_SINEA[15::], Y2_SINEA[15::], color = "#420404")
ax2.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax2.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax2.scatter(0.002, 0.34, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.005, -0.38, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.064, 0.02, color = "red", marker = "o", s = 200)
ax2.scatter(0.08, 0.02, color = "red", marker = "o", s = 200)
ax2.scatter(0.593, 0.75, color = "#AB0707", marker = "o", s = 200)
ax2.scatter(-0.579, -0.79, color = "#AB0707", marker = "o", s = 200)

ax2.text(-0.579 - 1.3*epsilon, -0.79 - 2.5*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(0.593 - 1.3*epsilon, 0.75 - 1.8*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(0.08 - 1.7*epsilon, 0.02 - 2.3*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.064 - 1.7*epsilon, 0.02 - 2.4*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.005 - 1.4*epsilon, -0.38 - 2.3*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.text(0.002 - 1.4*epsilon, 0.34 - 2.3*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")

fig.legend([lSB1, lSB2, lSB3], ["Saturación", "Coercitividad", "Retentividad"], loc = "lower right", fontsize = 15)
ax2.grid()

plt.savefig("Sine A.pdf")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

FN1_SINEB = pd.read_csv(path1 + "SINE B.csv", sep=';')
X1_SINEB = FN1_SINEB["Corriente"]
Y1_SINEB = FN1_SINEB["Flujo"]

FN2_SINEB = pd.read_csv(path2 + "SINE B.csv", sep=';')
X2_SINEB = FN2_SINEB["Corriente"]
Y2_SINEB = FN2_SINEB["Flujo"]

ax1.scatter(X1_SINEB[45::], Y1_SINEB[45::], color = "#420404")
ax1.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax1.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
lSB1 = ax1.scatter(-0.006, 0.32, color = "orange", marker = "o", s = 200)
ax1.scatter(-0.004, -0.21, color = "orange", marker = "o", s = 200)
lSB2 = ax1.scatter(0.219, -0.01, color = "red", marker = "o", s = 200)
ax1.scatter(-0.321, -0.01, color = "red", marker = "o", s = 200)
lSB3 = ax1.scatter(0.463, 0.40, color = "#AB0707", marker = "o", s = 200)
ax1.scatter(-0.464, -0.29, color = "#AB0707", marker = "o", s = 200)

ax1.text(-0.464 - 1*epsilon, -0.29 - 1.5*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.463 - 0.8*epsilon, 0.40 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(-0.321 - 1.1*epsilon, -0.01 - 1*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(0.219 - 1.3*epsilon, -0.01 - 1*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(-0.006 - 1.2*epsilon, 0.32 - 1.3*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.text(-0.004 - 1.2*epsilon, -0.21 - 1.2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.grid()

ax2.scatter(X2_SINEB[30::], Y2_SINEB[30::], color = "#420404")
ax2.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax2.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax2.scatter(0.003, 0.39, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.006, -0.16, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.102, -0.02, color = "red", marker = "o", s = 200)
ax2.scatter(0.03, -0.02, color = "red", marker = "o", s = 200)
ax2.scatter(-0.359, -0.46, color = "#AB0707", marker = "o", s = 200)
ax2.scatter(0.357, 0.69, color = "#AB0707", marker = "o", s = 200)

ax2.text(0.357 - 0.8*epsilon, 0.69 - 1.5*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(-0.359 - 0.8*epsilon, -0.46 - 1.6*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(0.03 - 1.1*epsilon, -0.02 - 1.7*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.102 - 1*epsilon, -0.02 - 1.7*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.006 - 0.7*epsilon, -0.16 - 2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.text(0.003 - 0.9*epsilon, 0.39 - 2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.grid()

fig.legend([lSB1, lSB2, lSB3], ["Saturación", "Coercitividad", "Retentividad"], loc = "lower right", fontsize = 15)
plt.savefig("Sine B.pdf")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

FN1_TRINA = pd.read_csv(path1 + "TRIN A.csv", sep=';')
X1_TRINA = FN1_TRINA["Corriente"]
Y1_TRINA = FN1_TRINA["Flujo"]

FN2_TRINA = pd.read_csv(path2 + "TRIN A.csv", sep=';')
X2_TRINA = FN2_TRINA["Corriente"]
Y2_TRINA = FN2_TRINA["Flujo"]

ax1.scatter(X1_TRINA[60::], Y1_TRINA[60::], color = "#420404")
ax1.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax1.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax1.scatter(0.007, 0.36, color = "orange", marker = "o", s = 200)
ax1.scatter(0.004, -0.22, color = "orange", marker = "o", s = 200)
ax1.scatter(-0.283, 0.01, color = "red", marker = "o", s = 200)
ax1.scatter(0.224, 0.02, color = "red", marker = "o", s = 200)
ax1.scatter(0.49, 0.44, color = "#AB0707", marker = "o", s = 200)
ax1.scatter(-0.49, -0.35, color = "#AB0707", marker = "o", s = 200)

ax1.text(-0.49 - 1*epsilon, -0.35 - 1.5*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.49 - 0.8*epsilon, 0.44 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.224 - 1.1*epsilon, 0.02 - 1.6*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(-0.283 - 1.3*epsilon, 0.01 - 1.3*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(0.004 - 1.2*epsilon, -0.22 - 1.3*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.text(0.007 - 1.2*epsilon, 0.36 - 1.2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.grid()

ax2.scatter(X2_TRINA[30::], Y2_TRINA[30::], color = "#420404")
ax2.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax2.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax2.scatter(0.005, 0.32, color = "orange", marker = "o", s = 200)
ax2.scatter(0.004, -0.37, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.06, 0.01, color = "red", marker = "o", s = 200)
ax2.scatter(0.072, -0.01, color = "red", marker = "o", s = 200)
ax2.scatter(-0.397, -0.72, color = "#AB0707", marker = "o", s = 200)
ax2.scatter(0.466, 0.67, color = "#AB0707", marker = "o", s = 200)

ax2.text(0.466 - 1*epsilon, 0.67 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(-0.397 - 1*epsilon, -0.72 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(0.072 - 1*epsilon, -0.01 - 1.7*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.06 - 1*epsilon, 0.01 - 1.7*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(0.004 - 1*epsilon, -0.37 - 1*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.text(0.005 - 1*epsilon, 0.32 - 1*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.grid()

fig.legend([lSB1, lSB2, lSB3], ["Saturación", "Coercitividad", "Retentividad"], loc = "lower right", fontsize = 15)
plt.savefig("Trinity A.pdf")

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (15, 5))

FN1_TRINB = pd.read_csv(path1 + "TRIN B.csv", sep=';')
X1_TRINB = FN1_TRINB["Corriente"]
Y1_TRINB = FN1_TRINB["Flujo"]

FN2_TRINB = pd.read_csv(path2 + "TRIN B.csv", sep=';')
X2_TRINB = FN2_TRINB["Corriente"]
Y2_TRINB = FN2_TRINB["Flujo"]

ax1.scatter(X1_TRINB[70:270], Y1_TRINB[70:270], color = "#420404")
ax1.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax1.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax1.scatter(0.004, 0.3, color = "orange", marker = "o", s = 200)
ax1.scatter(0.001, -0.1, color = "orange", marker = "o", s = 200)
ax1.scatter(-0.29, 0.01, color = "red", marker = "o", s = 200)
ax1.scatter(0.145, 0.01, color = "red", marker = "o", s = 200)
ax1.scatter(0.33, 0.35, color = "#AB0707", marker = "o", s = 200)
ax1.scatter(-0.358, -0.16, color = "#AB0707", marker = "o", s = 200)

ax1.text(-0.358 - 0.7*epsilon, -0.16 - 0.7*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.33 - 0.9*epsilon, 0.35 - 0.8*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax1.text(0.145 - 1*epsilon, 0.01 - 1*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(-0.29 - 1*epsilon, 0.01 - 1*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax1.text(0.001 - 0.9*epsilon, -0.1 - 1*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.text(0.004 - 0.9*epsilon, 0.3 - 1*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax1.grid()

ax2.scatter(X2_TRINB[70:270], Y2_TRINB[70:270], color = "#420404")
ax2.set_ylabel(r"Flujo Magnético $(\Phi_{B}) \propto B$", fontsize = 15)
ax2.set_xlabel(r"Corriente $(I) \propto H$", fontsize = 15)
ax2.scatter(0.005, 0.3, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.001, -0.23, color = "orange", marker = "o", s = 200)
ax2.scatter(-0.057, 0.02, color = "red", marker = "o", s = 200)
ax2.scatter(0.044, -0.02, color = "red", marker = "o", s = 200)
ax2.scatter(-0.27, -0.48, color = "#AB0707", marker = "o", s = 200)
ax2.scatter(0.254, 0.53, color = "#AB0707", marker = "o", s = 200)

ax2.text(0.254 - 0.5*epsilon, 0.53 - 1.3*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(-0.27 - 0.5*epsilon, -0.48 - 1*epsilon, "S", color = "orange", fontsize = 14, weight = "bold")
ax2.text(0.044 - 0.7*epsilon, -0.02 - 1.7*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.057 - 0.7*epsilon, 0.02 - 1.5*epsilon, "C", color = "#F6D409", fontsize = 14, weight = "bold")
ax2.text(-0.001 - 0.5*epsilon, -0.23 - 1.2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.text(0.005 - 0.6*epsilon, 0.3 - 1.2*epsilon, "R", color = "#AB0707", fontsize = 14, weight = "bold")
ax2.grid()

fig.legend([lSB1, lSB2, lSB3], ["Saturación", "Coercitividad", "Retentividad"], loc = "lower right", fontsize = 15)
plt.savefig("Trinity B.pdf")
