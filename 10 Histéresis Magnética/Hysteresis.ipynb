# %%
import pandas as pd
import numpy as np
import sympy as sym
from scipy import constants
import matplotlib.pyplot as plt
from scipy import optimize

# %%
path1 = "C:/Users/juank/Escritorio/Universidad/202320/Lab Moderna/Modern_Phy_Lab/10 Histéresis Magnética/First Nucleus.csv"
data1 = pd.read_csv(path1, sep=';')
data1
# Out:
#     Sinusoidal, 0.1Hz, 2V Unnamed: 1 Saturacion Unnamed: 3  \
# 0               Corriente      Flujo  Corriente      Flujo
# 1                   0.002          0      0.519       0.52
# 2                   0.007          0        NaN        NaN
# 3                   0.028          0   Integral  0,376 VsA
# 4                   0.051          0        NaN        NaN
# ..                    ...        ...        ...        ...
# 487                   NaN        NaN        NaN        NaN
# 488                   NaN        NaN        NaN        NaN
# 489                   NaN        NaN        NaN        NaN
# 490                   NaN        NaN        NaN        NaN
# 491                   NaN        NaN        NaN        NaN
#
#     Sinusoidal, 0.3Hz, 2V Unnamed: 5 Saturacion.1 Unnamed: 7  \
# 0               Corriente      Flujo    Corriente      Flujo
# 1                   0.004          0        0.462       0.39
# 2                    0.02          0          NaN        NaN
# ...

# %%
Y1 = data1["Sinusoidal, 0.1Hz, 2V"][1::].to_numpy()
Y1
# Out:
# array(['0.002', '0.007', '0.028', '0.051', '0.072', '0.092', '0.113',
#        '0.132', '0.151', '0.169', '0.184', '0.196', '0.206', '0.216',
#        '0.226', '0.235', '0.245', '0.257', '0.268', '0.281', '0.293',
#        '0.307', '0.321', '0.335', '0.348', '0.364', '0.38', '0.394',
#        '0.407', '0.421', '0.434', '0.446', '0.458', '0.469', '0.478',
#        '0.486', '0.494', '0.501', '0.506', '0.511', '0.516', '0.519',
#        '0.519', '0.519', '0.519', '0.517', '0.513', '0.507', '0.5',
#        '0.491', '0.48', '0.469', '0.454', '0.439', '0.421', '0.404',
#        '0.386', '0.367', '0.346', '0.327', '0.306', '0.285', '0.265',
#        '0.242', '0.221', '0.198', '0.176', '0.153', '0.131', '0.108',
#        '0.087', '0.065', '0.044', '0.022', '0.002', '-0.018', '-0.038',
#        '-0.057', '-0.075', '-0.092', '-0.108', '-0.123', '-0.137',
#        '-0.15', '-0.165', '-0.179', '-0.193', '-0.206', '-0.221',
#        '-0.234', '-0.249', '-0.263', '-0.276', '-0.289', '-0.302',
# ...

# %%
path2 = "C:/Users/juank/Escritorio/Universidad/202320/Lab Moderna/Modern_Phy_Lab/10 Histéresis Magnética/Second Nucleus.csv"
data2 = pd.read_csv(path2, sep = ";")
data2
# Out:
#     Sinusoidal, 0.1Hz, 2V Unnamed: 1 Saturacion Unnamed: 3  \
# 0               Corriente      Flujo  Corriente      Flujo
# 1                   0,002          0      0,596       0,75
# 2                   0,008          0        NaN        NaN
# 3                   0,005          0   Integral  0,242 VsA
# 4                   0,013       0,01        NaN        NaN
# ..                    ...        ...        ...        ...
# 504                   NaN        NaN        NaN        NaN
# 505                   NaN        NaN        NaN        NaN
# 506                   NaN        NaN        NaN        NaN
# 507                   NaN        NaN        NaN        NaN
# 508                   NaN        NaN        NaN        NaN
#
#     Sinusoidal, 0.3Hz, 2V Unnamed: 5 Saturacion.1 Unnamed: 7  \
# 0               Corriente      Flujo    Corriente      Flujo
# 1                   0,004          0        0,357        0,7
# 2                   0,018          0          NaN        NaN
# ...
